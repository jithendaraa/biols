# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
basepath = '/home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/er1-ws_datagen_fix_noise_interv_noise-chemdataproj-d005-D2500-multi-n_pairs2000-sets20-gaussianinterv/00'
images = np.load(f'{basepath}/x_samples.npy')
z_samples = np.load(f'{basepath}/z_samples.npy')
targets = np.load(f'{basepath}/interv_targets.npy')
noise = np.load(f'{basepath}/interv_noise.npy')
values = np.load(f'{basepath}/interv_values.npy')

# %%
plt.figure(figsize=(4, 4))
plt.imshow(images[0][:, :, 0], cmap='Purples')
plt.xticks([])
plt.yticks([])
plt.savefig('chemdata.pdf')
plt.savefig('chemdata.png')
plt.show()

# %%
# from PIL import Image
# im = Image.fromarray(images[3000][:, :, 0:1])
# im.save("chemdata.jpeg")

import matplotlib
matplotlib.image.imsave('name.png', images[3000][:, :, 0:1])

# im = Image.fromarray(images[0][:, :, :])
# im.save("interv_chemdata.jpeg")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 6
#       1 # from PIL import Image
#       2 # im = Image.fromarray(images[3000][:, :, 0:1])
#       3 # im.save("chemdata.jpeg")
#       5 import matplotlib
# ----> 6 matplotlib.image.imsave('name.png', images[3000][:, :, 0:1])
#       8 # im = Image.fromarray(images[0][:, :, :])
#       9 # im.save("interv_chemdata.jpeg")
#
# File ~/.conda/envs/mydibs/lib/python3.8/site-packages/matplotlib/image.py:1630, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1628     sm = cm.ScalarMappable(cmap=cmap)
#    1629     sm.set_clim(vmin, vmax)
# -> 1630     rgba = sm.to_rgba(arr, bytes=True)
#    1631 if pil_kwargs is None:
#    1632     pil_kwargs = {}
#
# File ~/.conda/envs/mydibs/lib/python3.8/site-packages/matplotlib/cm.py:490, in ScalarMappable.to_rgba(self, x, alpha, bytes, norm)
#     488     xx = x
#     489 else:
# --> 490     raise ValueError("Third dimension must be 3 or 4")
#     491 if xx.dtype.kind == 'f':
#     492     if norm and (xx.max() > 1 or xx.min() < 0):
#
# ValueError: Third dimension must be 3 or 4

# %%
images[0][:, :, 0:1].dtype
# Out:
# dtype('float32')

# %%
plt.figure(figsize=(4, 4))
plt.imshow(images[3000][:, :, 0], cmap='Purples')
plt.xticks([])
plt.yticks([])
plt.savefig('interv_chemdata.png')

# %%
images.shape
# Out:
# (4000, 50, 50, 3)
