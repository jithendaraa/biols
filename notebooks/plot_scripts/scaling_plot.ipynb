# %%
import sys
sys.path.append('..')
import wandb
from helpers.scaling_plot_helper import fetch_and_plot_scaling_curves

api = wandb.Api(timeout=40)
runs = api.runs("structurelearning/BIOLS")
max_steps = 20000
reqd_keys = ['Evaluations/SHD', 'Evaluations/AUROC', 'L_MSE']
basepath = '/home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/scaling_nodes_ablations'

# %%
fetch_and_plot_scaling_curves(
    num_nodes_list=[10, 15, 20, 25, 30, 40, 50],
    degree=1,
    num_interv=10000,
    basepath=basepath,
    runs=runs,
    reqd_keys=reqd_keys,
    proj='3_layer_mlp',
    interv_type='multi',
    interv_value='gaussian',
    box_widths=0.9
)
# Out:
# Saved to /home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/scaling_nodes_ablations/scaling_er1_projnonlinear_multi_100sets_gaussianinterv.pdf

# %%
fetch_and_plot_scaling_curves(
    num_nodes_list=[10, 15, 20, 25, 30, 40, 50],
    degree=1,
    num_interv=12000,
    basepath=basepath,
    runs=runs,
    reqd_keys=reqd_keys,
    proj='3_layer_mlp',
    interv_type='multi',
    interv_value='gaussian',
    box_widths=0.9
)
# Out:
# Saved to /home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/scaling_nodes_ablations/scaling_er1_projnonlinear_multi_120sets_gaussianinterv.pdf

# %%
fetch_and_plot_scaling_curves(
    num_nodes_list=[10, 15, 20, 25, 30, 40, 50],
    degree=1,
    num_interv=40000,
    basepath=basepath,
    runs=runs,
    reqd_keys=reqd_keys,
    proj='3_layer_mlp',
    interv_type='multi',
    interv_value='gaussian',
    box_widths=0.9
)
# Out:
# Saved to /home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/scaling_nodes_ablations/scaling_er1_projnonlinear_multi_400sets_gaussianinterv.pdf

# %%
fetch_and_plot_scaling_curves(
    num_nodes_list=[10, 15, 20, 25, 30, 40, 50],
    num_interv=10000,
    basepath=basepath,
    runs=runs,
    reqd_keys=reqd_keys,
    proj='linear',
    interv_type='multi',
    interv_value='gaussian',
    box_widths=0.9
)
# Out:
# Saved to /home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/scaling_nodes_ablations/scaling_er1_projlinear_multi_100sets_gaussianinterv.pdf

# %%
fetch_and_plot_scaling_curves(
    num_nodes_list=[10, 15, 20, 25, 30, 40, 50],
    num_interv=10000,
    basepath=basepath,
    runs=runs,
    reqd_keys=reqd_keys,
    proj='linear',
    interv_type='single',
    interv_value='gaussian',
    box_widths=0.9
)
# Out:
# Saved to /home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/scaling_nodes_ablations/scaling_er1_projlinear_single_100sets_gaussianinterv.pdf

# %%
fetch_and_plot_scaling_curves(
    num_nodes_list=[20, 25, 30, 40, 50],
    num_interv=10000,
    basepath=basepath,
    runs=runs,
    reqd_keys=reqd_keys,
    proj='linear',
    interv_type='multi',
    interv_value='zeros',
    box_widths=0.9
)
# Out:
# Saved to /home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/scaling_nodes_ablations/scaling_er1_projlinear_multi_100sets_zerosinterv.pdf
