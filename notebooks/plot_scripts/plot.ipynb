# %%
import sys
sys.path.append('..')
import wandb
from helpers.graph_density_ablation_helper import fetch_and_plot_graph_densities_ablation

api = wandb.Api(timeout=40)
runs = api.runs("structurelearning/BIOLS")
max_steps = 20000
reqd_keys = ['Evaluations/SHD', 'Evaluations/AUROC', 'L_MSE']
basepath = '/home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/graph_density_ablations'

# %%
fetch_and_plot_graph_densities_ablation(
    num_nodes=20, 
    num_interv=12000,
    graph_densities=[1, 2, 4], 
    basepath=basepath, 
    runs=runs, 
    reqd_keys=reqd_keys, 
    proj='linear',
    interv_type='multi',
    box_widths=0.5
)
# Out:
# Saved to /home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/graph_density_ablations/ablation_graph_density_d20_D100_projlinear_multi_120sets.pdf
# Legends saved at: /home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/graph_density_ablations/d20_D100_projlinear_multi_120sets_graph_density_ablation_legend.pdf

# %%
fetch_and_plot_graph_densities_ablation(
    num_nodes=30, 
    num_interv=12000,
    graph_densities=[1, 2, 4], 
    basepath=basepath, 
    runs=runs, 
    reqd_keys=reqd_keys, 
    proj='linear',
    interv_type='multi',
    box_widths=0.5
)
# Out:
# Saved to /home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/graph_density_ablations/ablation_graph_density_d30_D100_projlinear_multi_120sets.pdf
# Legends saved at: /home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/graph_density_ablations/d30_D100_projlinear_multi_120sets_graph_density_ablation_legend.pdf

# %%
fetch_and_plot_graph_densities_ablation(
    num_nodes=20, 
    num_interv=12000,
    graph_densities=[1, 2, 4], 
    basepath=basepath, 
    runs=runs, 
    reqd_keys=reqd_keys, 
    proj='3_layer_mlp',
    interv_type='multi',
    box_widths=0.5
)
# Out:
# Saved to /home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/graph_density_ablations/ablation_graph_density_d20_D100_projnonlinear_multi_120sets.pdf
# Legends saved at: /home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/graph_density_ablations/d20_D100_projnonlinear_multi_120sets_graph_density_ablation_legend.pdf

# %%
fetch_and_plot_graph_densities_ablation(
    num_nodes=30, 
    num_interv=12000,
    graph_densities=[1, 2, 4], 
    basepath=basepath, 
    runs=runs, 
    reqd_keys=reqd_keys, 
    proj='3_layer_mlp',
    interv_type='multi',
    box_widths=0.5
)
# Out:
# Saved to /home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/graph_density_ablations/ablation_graph_density_d30_D100_projnonlinear_multi_120sets.pdf
# Legends saved at: /home/mila/j/jithendaraa.subramanian/scratch/biols_datasets/graph_density_ablations/d30_D100_projnonlinear_multi_120sets_graph_density_ablation_legend.pdf
